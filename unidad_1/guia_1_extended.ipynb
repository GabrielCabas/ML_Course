# %%
#Instalen esto para simplificar strings (Servirá para homogeneizar las comunas)

# %%
# !pip install unidecode
# Out:
# ERROR: Invalid requirement: '#Instalen': Expected package name at the start of dependency specifier
#     #Instalen
#     ^

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from unidecode import unidecode
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# ## Importar datos

# %%
data = pd.read_csv("../datasets/guia_1/2023-03-08 Precios Casas RM.csv") #Dataset de precios
comunas = pd.read_csv("../datasets/guia_1/Latitud - Longitud Chile.csv") #Dataset de comunas

# %% [markdown]
# ## Feature engineering + EDA

# %%
#Veamos qué tal se ven las comunas
comunas = comunas[comunas["Región"] == "Metropolitana de Santiago"] #Seleccionamos las comunas que están en santiago
comunas.Comuna.unique() #Fíjense en cómo están escritas, con espacios y tildes.
# Out:
# array(['Santiago', 'Cerrillos', 'Cerro Navia', 'Conchalí', 'El Bosque',
#        'Estación Central', 'Huechuraba', 'Independencia', 'La Cisterna',
#        'La Florida', 'La Granja', 'La Pintana', 'La Reina', 'Las Condes',
#        'Lo Barnechea', 'Lo Espejo', 'Lo Prado', 'Macul', 'Maipú', 'Ñuñoa',
#        'Pedro Aguirre Cerda', 'Peñalolén', 'Providencia', 'Pudahuel',
#        'Quilicura', 'Quinta Normal', 'Recoleta', 'Renca', 'San Joaquín',
#        'San Miguel', 'San Ramón', 'Vitacura', 'Puente Alto', 'Pirque',
#        'San José de Maipo', 'Colina', 'Lampa', 'Til Til', 'San Bernardo',
#        'Buin', 'Calera de Tango', 'Paine', 'Melipilla', 'Alhué',
#        'Curacaví', 'María Pinto', 'San Pedro', 'Talagante', 'El Monte',
#        'Isla de Maipo', 'Padre Hurtado', 'Peñaflor'], dtype=object)

# %%
#Primero vamos a transformar los string en el dataset de comunas
comunas["Comuna"] = comunas.Comuna.str.replace(" ", "") #Vamos a quitarles los espacios
comunas["Comuna"] = comunas["Comuna"].apply(unidecode) #Quitamos caracteres extraños como tildes
comunas["Comuna"] = comunas["Comuna"].str.lower() #Dejamos en minusculas
comunas.head()
# Out:
#      CUT (Código Único Territorial)      Comuna Provincia  \
# 257                           13101    santiago  Santiago
# 258                           13102   cerrillos  Santiago
# 259                           13103  cerronavia  Santiago
# 260                           13104    conchali  Santiago
# 261                           13105    elbosque  Santiago
#
#                         Región  Superficie (km2)  Población Año 2017  \
# 257  Metropolitana de Santiago             23.20             404,495
# 258  Metropolitana de Santiago             21.00              80,832
# 259  Metropolitana de Santiago             11.00             132,622
# 260  Metropolitana de Santiago             10.70             126,955
# 261  Metropolitana de Santiago             14.20             162,505
#
#      Densidad (hab./km2)  IDH 2005  Latitud (Decimal)  Longitud (decimal)  \
# 257              17435.1     0.807           -33.4372            -70.6572
# 258               3849.1     0.743           -33.5000            -70.7167
# 259              12056.5     0.683           -33.4219            -70.7350
# 260              11865.0     0.707           -33.3800            -70.6750
# 261              11444.0     0.711           -33.5669            -70.6750
#
#     Latitud (Sexagesimal) Longitud (Sexagesimal)
# 257           -33°26' 14"            -70°39' 26"
# 258            -33°30' 0"             -70°43' 0"
# 259         -33°25' 19''              -70°44' 6"
# 260           -33°22' 48"            -70°40' 30"
# 261          -33°34' 1''             -70°40' 30"

# %%
#Ahora en el dataset de precios
data["Comuna"] = data["Comuna"].apply(unidecode) #Quitamos caracteres extraños
data["Comuna"] = data["Comuna"].str.lower() #Dejamos en minusculas
data
# Out:
#        Price_CLP  Price_UF  Price_USD             Comuna  \
# 0      409285000     11500     509695       quintanormal
# 1      105000000      2950     130760  pedroaguirrecerda
# 2      128124000      3600     159557    estacioncentral
# 3       75000000      2107      93400             colina
# 4       53000000      1489      66002             colina
# ...          ...       ...        ...                ...
# 7774  2491300000     70000    3102491          lascondes
# 7775   242012000      6800     301385          penalolen
# 7776  3736950000    105000    4653736          lascondes
# 7777   569440000     16000     709141          lapintana
# 7778   355828820      9998     443124          talagante
#
#                              Ubicacion  Dorms  Baths  Built Area  Total Area  \
# 0                      Hoevel4548y4558      7    4.0       384.0       732.0
# 1                             Rucalhue      2    1.0       112.0       145.0
# 2                   AvenidaLasParcelas      3    1.0        59.0       243.0
# 3                   PasajeGonzaloRojas      3    1.0       103.0        73.0
# 4                HernánDíazArrieta2820      2    1.0        57.0        67.0
# ...                                ...    ...    ...         ...         ...
# 7774            CalleSanJosédeLaSierra      5    5.0       600.0      1800.0
# 7775                    PasajeMarNegro      4    2.0       124.0       200.0
# 7776  CaminoLasFlores/CaminoPiedraRoja      5    7.0       460.0      4925.0
# 7777           LosCipreses/LosDuraznos      4    2.0       311.0      2011.0
# 7778            LucasPacheco/Balmaceda      5    3.0       225.0       366.0
#
#       Parking        id                       Realtor
# 0         3.0  11700213                           NaN
# 1         1.0  10894299     Legales y Propiedades SpA
# 2         2.0  10257635                 Propiedadesrs
# 3         1.0   9232092  Patricio Gajardo propiedades
# 4         1.0   7085397  Patricio Gajardo propiedades
# ...       ...       ...                           ...
# 7774      5.0   4708915   Propiedades Viña Limitada ®
# 7775      1.0   6641660                           NaN
# 7776      8.0   6032811                  Tsi Property
# 7777      1.0   5314376                  Tsi Property
# 7778      NaN   6186867                  Tsi Property
#
# [7779 rows x 12 columns]

# %%
data = data.merge(comunas, on="Comuna", how="left")
data
# Out:
#        Price_CLP  Price_UF  Price_USD             Comuna  \
# 0      409285000     11500     509695       quintanormal
# 1      105000000      2950     130760  pedroaguirrecerda
# 2      128124000      3600     159557    estacioncentral
# 3       75000000      2107      93400             colina
# 4       53000000      1489      66002             colina
# ...          ...       ...        ...                ...
# 7774  2491300000     70000    3102491          lascondes
# 7775   242012000      6800     301385          penalolen
# 7776  3736950000    105000    4653736          lascondes
# 7777   569440000     16000     709141          lapintana
# 7778   355828820      9998     443124          talagante
#
#                              Ubicacion  Dorms  Baths  Built Area  Total Area  \
# 0                      Hoevel4548y4558      7    4.0       384.0       732.0
# 1                             Rucalhue      2    1.0       112.0       145.0
# 2                   AvenidaLasParcelas      3    1.0        59.0       243.0
# 3                   PasajeGonzaloRojas      3    1.0       103.0        73.0
# 4                HernánDíazArrieta2820      2    1.0        57.0        67.0
# ...                                ...    ...    ...         ...         ...
# 7774            CalleSanJosédeLaSierra      5    5.0       600.0      1800.0
# 7775                    PasajeMarNegro      4    2.0       124.0       200.0
# 7776  CaminoLasFlores/CaminoPiedraRoja      5    7.0       460.0      4925.0
# 7777           LosCipreses/LosDuraznos      4    2.0       311.0      2011.0
# 7778            LucasPacheco/Balmaceda      5    3.0       225.0       366.0
#
#       Parking  ...  Provincia                     Región   Superficie (km2)   \
# 0         3.0  ...   Santiago  Metropolitana de Santiago              13.00
# 1         1.0  ...   Santiago  Metropolitana de Santiago              10.00
# 2         2.0  ...   Santiago  Metropolitana de Santiago              15.00
# 3         1.0  ...  Chacabuco  Metropolitana de Santiago             971.20
# 4         1.0  ...  Chacabuco  Metropolitana de Santiago             971.20
# ...       ...  ...        ...                        ...                 ...
# 7774      5.0  ...   Santiago  Metropolitana de Santiago              99.00
# 7775      1.0  ...   Santiago  Metropolitana de Santiago              54.00
# 7776      8.0  ...   Santiago  Metropolitana de Santiago              99.00
# 7777      1.0  ...   Santiago  Metropolitana de Santiago              30.60
# 7778      NaN  ...  Talagante  Metropolitana de Santiago             126.00
#
#      Población Año 2017 Densidad (hab./km2) IDH 2005 Latitud (Decimal)  \
# 0               110,026              8463.5    0.723          -33.4269
# 1               101,174             10117.4    0.708          -33.4661
# 2               147,041              9802.7    0.735          -33.4589
# 3               146,207               150.5    0.726          -33.1939
# 4               146,207               150.5    0.726          -33.1939
# ...                 ...                 ...      ...               ...
# 7774            294,838              2978.2    0.933          -33.4167
# 7775            241,599              4474.1    0.743          -33.4861
# 7776            294,838              2978.2    0.933          -33.4167
# 7777            177,335              5795.3    0.679          -33.5828
# 7778             74,237               589.2    0.749          -33.6669
#
#       Longitud (decimal)  Latitud (Sexagesimal)  Longitud (Sexagesimal)
# 0               -70.6989          -33°25' 37''            -70°41' 56''
# 1               -70.6336          -33°27' 58''             -70°38' 1''
# 2               -70.6989          -33°27' 32''            -70°41' 56''
# 3               -70.6678          -33°11' 38''             -70°40' 4''
# 4               -70.6678          -33°11' 38''             -70°40' 4''
# ...                  ...                    ...                     ...
# 7774            -70.5833             -33°25' 0"              -70°35' 0"
# 7775            -70.5333          -33°29' 10''               -70°32' 0"
# 7776            -70.5833             -33°25' 0"              -70°35' 0"
# 7777            -70.6339          -33°34' 58''             -70°38' 2''
# 7778            -70.9308           -33°40' 1''            -70°55' 51''
#
# [7779 rows x 23 columns]

# %%
#Eliminemos algunas columnas inutiles y estandaricemos los nombres de las columnas
data = data.drop(columns=["Price_CLP", "Price_USD", "id", "Realtor", "CUT (Código Único Territorial)",
                          "Provincia", "Región", "Ubicacion", "Latitud (Sexagesimal)", "Longitud (Sexagesimal)"])
data.columns=["price", "comuna", "dorms", "baths", "built_area", "total_area", "parking", "superficie_comuna", "poblacion_comuna", "densidad_comuna", "idh_comuna", "lat_comuna", "long_comuna" ]
data
# Out:
#        price             comuna  dorms  baths  built_area  total_area  \
# 0      11500       quintanormal      7    4.0       384.0       732.0
# 1       2950  pedroaguirrecerda      2    1.0       112.0       145.0
# 2       3600    estacioncentral      3    1.0        59.0       243.0
# 3       2107             colina      3    1.0       103.0        73.0
# 4       1489             colina      2    1.0        57.0        67.0
# ...      ...                ...    ...    ...         ...         ...
# 7774   70000          lascondes      5    5.0       600.0      1800.0
# 7775    6800          penalolen      4    2.0       124.0       200.0
# 7776  105000          lascondes      5    7.0       460.0      4925.0
# 7777   16000          lapintana      4    2.0       311.0      2011.0
# 7778    9998          talagante      5    3.0       225.0       366.0
#
#       parking superficie_comuna poblacion_comuna  densidad_comuna  idh_comuna  \
# 0         3.0            13.00           110,026           8463.5       0.723
# 1         1.0            10.00           101,174          10117.4       0.708
# 2         2.0            15.00           147,041           9802.7       0.735
# 3         1.0           971.20           146,207            150.5       0.726
# 4         1.0           971.20           146,207            150.5       0.726
# ...       ...               ...              ...              ...         ...
# 7774      5.0            99.00           294,838           2978.2       0.933
# 7775      1.0            54.00           241,599           4474.1       0.743
# 7776      8.0            99.00           294,838           2978.2       0.933
# 7777      1.0            30.60           177,335           5795.3       0.679
# 7778      NaN           126.00            74,237            589.2       0.749
#
#       lat_comuna  long_comuna
# 0       -33.4269     -70.6989
# 1       -33.4661     -70.6336
# 2       -33.4589     -70.6989
# 3       -33.1939     -70.6678
# 4       -33.1939     -70.6678
# ...          ...          ...
# 7774    -33.4167     -70.5833
# 7775    -33.4861     -70.5333
# 7776    -33.4167     -70.5833
# 7777    -33.5828     -70.6339
# 7778    -33.6669     -70.9308
#
# [7779 rows x 13 columns]

# %%
plt.figure(figsize=(10,6))
sns.countplot(data, x="comuna") #Cuenta cuantas comunas hay en el dataset
plt.title("Distribución de casas por comuna") #El título
plt.xticks(rotation=90) #Rota los nombres de las comunas para que quepan en el plot
plt.show()

# %%
data.describe() #Describamos los datos numéricos
# Out:
#                price        dorms        baths     built_area     total_area  \
# count    7779.000000  7779.000000  7714.000000    7533.000000    7571.000000
# mean    10234.571153     3.994087     2.653746     229.923669     807.919826
# std     10870.491584     1.622821     1.465103    1676.898812    9050.893115
# min         0.000000     1.000000     1.000000       1.000000       1.000000
# 25%      3372.000000     3.000000     2.000000      85.000000     129.500000
# 50%      5760.000000     4.000000     2.000000     128.000000     210.000000
# 75%     13800.000000     5.000000     3.000000     200.000000     443.000000
# max    155000.000000    27.000000    29.000000  120000.000000  678000.000000
#
#            parking  densidad_comuna   idh_comuna   lat_comuna  long_comuna
# count  5489.000000      7779.000000  7779.000000  7779.000000  7779.000000
# mean      2.980506      5022.160352     0.801947   -33.466522   -70.648303
# std      17.749384      4451.350901     0.083812     0.122765     0.109601
# min       1.000000         3.640000     0.657000   -33.900000   -71.466700
# 25%       1.000000      1943.900000     0.726000   -33.528900   -70.698900
# 50%       2.000000      3849.600000     0.773000   -33.453900   -70.633900
# 75%       3.000000      6455.800000     0.902000   -33.405800   -70.570000
# max    1269.000000     17435.100000     0.949000   -33.085000   -70.352800

# %%
data = data.drop(columns=["comuna"]) #Borra las comunas para quedarnos solo con valores numéricos
data #Vemos que hay valores nulos, además hay algunos valores que sabemos que son numéricos, que tienen una "," y otros un "." (densidad_comuna, poblacion_comuna)
# Out:
#        price  dorms  baths  built_area  total_area  parking superficie_comuna  \
# 0      11500      7    4.0       384.0       732.0      3.0            13.00
# 1       2950      2    1.0       112.0       145.0      1.0            10.00
# 2       3600      3    1.0        59.0       243.0      2.0            15.00
# 3       2107      3    1.0       103.0        73.0      1.0           971.20
# 4       1489      2    1.0        57.0        67.0      1.0           971.20
# ...      ...    ...    ...         ...         ...      ...               ...
# 7774   70000      5    5.0       600.0      1800.0      5.0            99.00
# 7775    6800      4    2.0       124.0       200.0      1.0            54.00
# 7776  105000      5    7.0       460.0      4925.0      8.0            99.00
# 7777   16000      4    2.0       311.0      2011.0      1.0            30.60
# 7778    9998      5    3.0       225.0       366.0      NaN           126.00
#
#      poblacion_comuna  densidad_comuna  idh_comuna  lat_comuna  long_comuna
# 0             110,026           8463.5       0.723    -33.4269     -70.6989
# 1             101,174          10117.4       0.708    -33.4661     -70.6336
# 2             147,041           9802.7       0.735    -33.4589     -70.6989
# 3             146,207            150.5       0.726    -33.1939     -70.6678
# 4             146,207            150.5       0.726    -33.1939     -70.6678
# ...               ...              ...         ...         ...          ...
# 7774          294,838           2978.2       0.933    -33.4167     -70.5833
# 7775          241,599           4474.1       0.743    -33.4861     -70.5333
# 7776          294,838           2978.2       0.933    -33.4167     -70.5833
# 7777          177,335           5795.3       0.679    -33.5828     -70.6339
# 7778           74,237            589.2       0.749    -33.6669     -70.9308
#
# [7779 rows x 12 columns]

# %%
data.dtypes #Fíjense que si vemos los tipos de datos: poblacion y superficie tienen tipo "object". Eso indica que están como texto
# Out:
# price                  int64
# dorms                  int64
# baths                float64
# built_area           float64
# total_area           float64
# parking              float64
# superficie_comuna     object
# poblacion_comuna      object
# densidad_comuna      float64
# idh_comuna           float64
# lat_comuna           float64
# long_comuna          float64
# dtype: object

# %%
def parse_column_to_float(data, column):
    data[column] = data[column].str.replace(" ", "") #Vamos a eliminar espacios " "
    data[column] = data[column].str.replace(",", "") #Vamos a eliminar comas
    data[column] = data[column].astype(float) #Vamos a transformar a float
    return data

parse_column_to_float(data, "superficie_comuna")
parse_column_to_float(data, "poblacion_comuna")
# Out:
#        price  dorms  baths  built_area  total_area  parking  \
# 0      11500      7    4.0       384.0       732.0      3.0
# 1       2950      2    1.0       112.0       145.0      1.0
# 2       3600      3    1.0        59.0       243.0      2.0
# 3       2107      3    1.0       103.0        73.0      1.0
# 4       1489      2    1.0        57.0        67.0      1.0
# ...      ...    ...    ...         ...         ...      ...
# 7774   70000      5    5.0       600.0      1800.0      5.0
# 7775    6800      4    2.0       124.0       200.0      1.0
# 7776  105000      5    7.0       460.0      4925.0      8.0
# 7777   16000      4    2.0       311.0      2011.0      1.0
# 7778    9998      5    3.0       225.0       366.0      NaN
#
#       superficie_comuna  poblacion_comuna  densidad_comuna  idh_comuna  \
# 0                  13.0          110026.0           8463.5       0.723
# 1                  10.0          101174.0          10117.4       0.708
# 2                  15.0          147041.0           9802.7       0.735
# 3                 971.2          146207.0            150.5       0.726
# 4                 971.2          146207.0            150.5       0.726
# ...                 ...               ...              ...         ...
# 7774               99.0          294838.0           2978.2       0.933
# 7775               54.0          241599.0           4474.1       0.743
# 7776               99.0          294838.0           2978.2       0.933
# 7777               30.6          177335.0           5795.3       0.679
# 7778              126.0           74237.0            589.2       0.749
#
#       lat_comuna  long_comuna
# 0       -33.4269     -70.6989
# 1       -33.4661     -70.6336
# 2       -33.4589     -70.6989
# 3       -33.1939     -70.6678
# 4       -33.1939     -70.6678
# ...          ...          ...
# 7774    -33.4167     -70.5833
# 7775    -33.4861     -70.5333
# 7776    -33.4167     -70.5833
# 7777    -33.5828     -70.6339
# 7778    -33.6669     -70.9308
#
# [7779 rows x 12 columns]

# %%
data.dtypes #Ahora si hay sólo valores numéricos
# Out:
# price                  int64
# dorms                  int64
# baths                float64
# built_area           float64
# total_area           float64
# parking              float64
# superficie_comuna    float64
# poblacion_comuna     float64
# densidad_comuna      float64
# idh_comuna           float64
# lat_comuna           float64
# long_comuna          float64
# dtype: object

# %%
data.describe() #Genial :D
# Out:
#                price        dorms        baths     built_area     total_area  \
# count    7779.000000  7779.000000  7714.000000    7533.000000    7571.000000
# mean    10234.571153     3.994087     2.653746     229.923669     807.919826
# std     10870.491584     1.622821     1.465103    1676.898812    9050.893115
# min         0.000000     1.000000     1.000000       1.000000       1.000000
# 25%      3372.000000     3.000000     2.000000      85.000000     129.500000
# 50%      5760.000000     4.000000     2.000000     128.000000     210.000000
# 75%     13800.000000     5.000000     3.000000     200.000000     443.000000
# max    155000.000000    27.000000    29.000000  120000.000000  678000.000000
#
#            parking  superficie_comuna  poblacion_comuna  densidad_comuna  \
# count  5489.000000        7779.000000       7779.000000      7779.000000
# mean      2.980506         223.045443     252498.699319      5022.160352
# std      17.749384         381.107019     169093.502147      4451.350901
# min       1.000000           7.000000       9726.000000         3.640000
# 25%       1.000000          23.200000     105833.000000      1943.900000
# 50%       2.000000          88.000000     208237.000000      3849.600000
# 75%       3.000000         155.000000     366916.000000      6455.800000
# max    1269.000000        4994.800000     568106.000000     17435.100000
#
#         idh_comuna   lat_comuna  long_comuna
# count  7779.000000  7779.000000  7779.000000
# mean      0.801947   -33.466522   -70.648303
# std       0.083812     0.122765     0.109601
# min       0.657000   -33.900000   -71.466700
# 25%       0.726000   -33.528900   -70.698900
# 50%       0.773000   -33.453900   -70.633900
# 75%       0.902000   -33.405800   -70.570000
# max       0.949000   -33.085000   -70.352800

# %%
#Veamos si tenemos valores nulos
def count_nulls(data):
    for column in data.columns: #Iterar las columnas
        print(column, len(data[data[column].isna()])) #Ver la cantidad de nulos
count_nulls(data)
# Out:
# price 0
# dorms 0
# baths 65
# built_area 246
# total_area 208
# parking 2290
# superficie_comuna 0
# poblacion_comuna 0
# densidad_comuna 0
# idh_comuna 0
# lat_comuna 0
# long_comuna 0

# %%
#Vamos a ver qué podemos hacer para tratar los nulos.
#Primero, no hay casas sin baño XD así que no le podemos asignar el valor 0
data.corr()["baths"].sort_values(ascending=False) #Calculamos la correlación y ordenamos de forma descendente
#Fíjense que existe una correlación fuerte entre la cantidad de dormitorios y la cantidad de baños.
# Out:
# baths                1.000000
# price                0.637613
# dorms                0.590074
# lat_comuna           0.314237
# idh_comuna           0.285408
# superficie_comuna    0.247325
# long_comuna          0.190030
# parking              0.064973
# built_area           0.053064
# total_area           0.051553
# densidad_comuna     -0.187750
# poblacion_comuna    -0.201133
# Name: baths, dtype: float64

# %%
#Vamos a ver cómo se distribuyen los baños en relación a la cantidad de dormitorios
sns.jointplot(data, x="dorms", y="baths", kind="hex")
plt.xlim(0, 10.5)
plt.ylim(0, 10.5)
#Efectivamente se ve una tendencia positiva
# Out:
# (0.0, 10.5)

# %%
sns.boxplot(data[data.baths.isna()], y="dorms", showfliers=False) #La distribución de filas sin baño está centrada entre 2 y 5 dormitorios. Sin considerar los outliers. 
#Podemos solucionar estos casos y el resto descartar por ser outliers.
# Out:
# <Axes: ylabel='dorms'>

# %%
data.loc[(data["baths"].isna()) & (data["dorms"] == 2), "baths"] = 1 #Si tiene dos dormitorios, diremos que tiene 1 baño
data.loc[(data["baths"].isna()) & (data["dorms"] == 3), "baths"] = 2 #Si tiene dos dormitorios, diremos que tiene 1 baño
data.loc[(data["baths"].isna()) & (data["dorms"] == 4), "baths"] = 3 #Si tiene dos dormitorios, diremos que tiene 1 baño
data.loc[(data["baths"].isna()) & (data["dorms"] == 4), "baths"] = 4 #Si tiene dos dormitorios, diremos que tiene 1 baño
data[data.baths.isna()] #Entonces, estos serían nuestros valores outlier que no nos interesa mucho utilizar
# Out:
#       price  dorms  baths  built_area  total_area  parking  superficie_comuna  \
# 498    4496      5    NaN       150.0       171.0      NaN               12.9
# 784   60000     14    NaN     60000.0     60000.0      NaN             4994.8
# 1077   8500     13    NaN       350.0       198.0      NaN               16.0
# 1078   8500     13    NaN       350.0       198.0      NaN               16.0
# 1926  18390      1    NaN         1.0       613.0      NaN               23.2
# 2046  24900      5    NaN       380.0       908.0      4.0             1024.0
# 2211  21990      5    NaN       250.0      2500.0      8.0               23.0
# 2421  34000      5    NaN       330.0       304.0      3.0               99.0
# 2652   2107      1    NaN         NaN         NaN      NaN               23.2
# 2788   3934     12    NaN       270.0       480.0      NaN               11.0
# 3963   4215      5    NaN       118.0       110.0      2.0               88.0
# 5251  26887      7    NaN       500.0      1760.0      NaN               12.9
# 6005   3512      1    NaN       170.0       170.0      1.0                9.7
# 6045  15000      1    NaN       127.0      2945.0      3.0              971.2
# 6401  41000      5    NaN       220.0       800.0      NaN               99.0
#
#       poblacion_comuna  densidad_comuna  idh_comuna  lat_comuna  long_comuna
# 498           116534.0          9033.60       0.806    -33.4869     -70.6039
# 784            18189.0             3.64       0.759    -33.6439     -70.3528
# 1077          157851.0          9865.70       0.697    -33.4058     -70.6400
# 1078          157851.0          9865.70       0.697    -33.4058     -70.6400
# 1926          404495.0         17435.10       0.807    -33.4372     -70.6572
# 2046          105833.0           103.40       0.912    -33.3500     -70.5167
# 2211           92787.0          4034.20       0.883    -33.4428     -70.5319
# 2421          294838.0          2978.20       0.933    -33.4167     -70.5833
# 2652          404495.0         17435.10       0.807    -33.4372     -70.6572
# 2788          132622.0         12056.50       0.683    -33.4219     -70.7350
# 3963          568106.0          6455.80       0.773    -33.6158     -70.5700
# 5251          116534.0          9033.60       0.806    -33.4869     -70.6039
# 6005           94492.0          9741.40       0.719    -33.4908     -70.6278
# 6045          146207.0           150.50       0.726    -33.1939     -70.6678
# 6401          294838.0          2978.20       0.933    -33.4167     -70.5833

# %%
#Removemos los nulos de los baños que no fueron inputados
data = data[data.baths.notna()]
data
# Out:
#        price  dorms  baths  built_area  total_area  parking  \
# 0      11500      7    4.0       384.0       732.0      3.0
# 1       2950      2    1.0       112.0       145.0      1.0
# 2       3600      3    1.0        59.0       243.0      2.0
# 3       2107      3    1.0       103.0        73.0      1.0
# 4       1489      2    1.0        57.0        67.0      1.0
# ...      ...    ...    ...         ...         ...      ...
# 7774   70000      5    5.0       600.0      1800.0      5.0
# 7775    6800      4    2.0       124.0       200.0      1.0
# 7776  105000      5    7.0       460.0      4925.0      8.0
# 7777   16000      4    2.0       311.0      2011.0      1.0
# 7778    9998      5    3.0       225.0       366.0      NaN
#
#       superficie_comuna  poblacion_comuna  densidad_comuna  idh_comuna  \
# 0                  13.0          110026.0           8463.5       0.723
# 1                  10.0          101174.0          10117.4       0.708
# 2                  15.0          147041.0           9802.7       0.735
# 3                 971.2          146207.0            150.5       0.726
# 4                 971.2          146207.0            150.5       0.726
# ...                 ...               ...              ...         ...
# 7774               99.0          294838.0           2978.2       0.933
# 7775               54.0          241599.0           4474.1       0.743
# 7776               99.0          294838.0           2978.2       0.933
# 7777               30.6          177335.0           5795.3       0.679
# 7778              126.0           74237.0            589.2       0.749
#
#       lat_comuna  long_comuna
# 0       -33.4269     -70.6989
# 1       -33.4661     -70.6336
# 2       -33.4589     -70.6989
# 3       -33.1939     -70.6678
# 4       -33.1939     -70.6678
# ...          ...          ...
# 7774    -33.4167     -70.5833
# 7775    -33.4861     -70.5333
# 7776    -33.4167     -70.5833
# 7777    -33.5828     -70.6339
# 7778    -33.6669     -70.9308
#
# [7764 rows x 12 columns]

# %%
#Nos quedan algunas otras columnas por solucionar
count_nulls(data)
# Out:
# price 0
# dorms 0
# baths 0
# built_area 245
# total_area 207
# parking 2281
# superficie_comuna 0
# poblacion_comuna 0
# densidad_comuna 0
# idh_comuna 0
# lat_comuna 0
# long_comuna 0

# %%
#Vamos con el parking.
data.describe() #El valor mínimo del parking es 1. Sabemos que en la realidad, se venden casas sin estacionamiento.
#Así que asumiremos que el valor nulo en el estacionamiento corresponde a "0"
# Out:
#                price        dorms        baths     built_area     total_area  \
# count    7764.000000  7764.000000  7764.000000    7519.000000    7557.000000
# mean    10218.611283     3.989825     2.650309     221.944275     800.000529
# std     10851.732786     1.609349     1.462291    1530.341494    9033.562916
# min         0.000000     1.000000     1.000000       1.000000       1.000000
# 25%      3372.000000     3.000000     2.000000      85.000000     129.000000
# 50%      5756.500000     4.000000     2.000000     128.000000     210.000000
# 75%     13800.000000     5.000000     3.000000     200.000000     442.000000
# max    155000.000000    27.000000    29.000000  120000.000000  678000.000000
#
#            parking  superficie_comuna  poblacion_comuna  densidad_comuna  \
# count  5483.000000        7764.000000       7764.000000      7764.000000
# mean      2.979938         222.520170     252586.515971      5017.544402
# std      17.758934         377.331755     169120.919945      4447.783277
# min       1.000000           7.000000       9726.000000         3.640000
# 25%       1.000000          23.200000     105833.000000      1943.900000
# 50%       2.000000          88.000000     208237.000000      3849.600000
# 75%       3.000000         155.000000     366916.000000      6455.800000
# max    1269.000000        4994.800000     568106.000000     17435.100000
#
#         idh_comuna   lat_comuna  long_comuna
# count  7764.000000  7764.000000  7764.000000
# mean      0.801958   -33.466567   -70.648400
# std       0.083812     0.122800     0.109621
# min       0.657000   -33.900000   -71.466700
# 25%       0.726000   -33.528900   -70.698900
# 50%       0.773000   -33.453900   -70.633900
# 75%       0.902000   -33.405800   -70.570000
# max       0.949000   -33.085000   -70.352800

# %%
data["parking"] = data["parking"].fillna(0) #Asignamos 0 a los parking nulos
count_nulls(data)
# Out:
# price 0
# dorms 0
# baths 0
# built_area 245
# total_area 207
# parking 0
# superficie_comuna 0
# poblacion_comuna 0
# densidad_comuna 0
# idh_comuna 0
# lat_comuna 0
# long_comuna 0
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_6296\1169348495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["parking"] = data["parking"].fillna(0) #Asignamos 0 a los parking nulos

# %%
#Nos queda built area y total area ¿Cómo los podemos solucionar?
data.corr()["total_area"].sort_values(ascending=False)
#Las correlaciones son mas leves, por la que no nos combiene fiarnos de sólo una feature para asignar.
# Out:
# total_area           1.000000
# built_area           0.361784
# price                0.075116
# superficie_comuna    0.064944
# baths                0.051637
# lat_comuna           0.046814
# dorms                0.033995
# parking              0.009872
# idh_comuna           0.009777
# long_comuna         -0.007174
# densidad_comuna     -0.030257
# poblacion_comuna    -0.040891
# Name: total_area, dtype: float64

# %%
data = data.dropna() #Estos sí los vamos a eliminar simplemente
count_nulls(data) #Nos quedamos sin nulos
# Out:
# price 0
# dorms 0
# baths 0
# built_area 0
# total_area 0
# parking 0
# superficie_comuna 0
# poblacion_comuna 0
# densidad_comuna 0
# idh_comuna 0
# lat_comuna 0
# long_comuna 0

# %%
def make_boxplots(data, column):
    plt.figure(figsize=(5,3))
    sns.boxplot(data, y=column)
    plt.show()

# %%
for column in data.columns:
    make_boxplots(data, column) #Mostremos las distribuciones de las features

# %%
#Filter data using Inter quantile range
def iqr(data, column): #Inter quantile range
    q3 = data[column].quantile(0.75) #3er cuartil
    q1 = data[column].quantile(0.25) #1er cuartil
    superior_limit = q3 + 1.5*(q3 - q1)
    inferior_limit = q1 - 1.5*(q3 - q1)
    return data[(data[column] < superior_limit) & (data[column] > inferior_limit)] #Selects data

# %%
for col in data.columns: #Iteration
    data = iqr(data, col) #Uses IQR
    make_boxplots(data, col) #Plot distr

# %%
data #Entonces este es el dataset que vamos a manejar
# Out:
#       price  dorms  baths  built_area  total_area  parking  superficie_comuna  \
# 1      2950      2    1.0       112.0       145.0      1.0               10.0
# 2      3600      3    1.0        59.0       243.0      2.0               15.0
# 5      2641      2    1.0        72.0       131.0      0.0               15.0
# 7      2950      2    1.0        50.0       120.0      1.0               70.2
# 8      2135      3    1.0        72.0        72.0      1.0              135.5
# ...     ...    ...    ...         ...         ...      ...                ...
# 7768   5300      4    2.0       114.0       220.0      3.0               15.0
# 7769   1264      3    2.0        40.0        50.0      1.0                7.0
# 7772   2390      5    1.0       120.0        76.0      1.0              155.0
# 7775   6800      4    2.0       124.0       200.0      1.0               54.0
# 7778   9998      5    3.0       225.0       366.0      0.0              126.0
#
#       poblacion_comuna  densidad_comuna  idh_comuna  lat_comuna  long_comuna
# 1             101174.0          10117.4       0.708    -33.4661     -70.6336
# 2             147041.0           9802.7       0.735    -33.4589     -70.6989
# 5             147041.0           9802.7       0.735    -33.4589     -70.6989
# 7             366916.0           5226.7       0.804    -33.5250     -70.5378
# 8             521657.0           3849.6       0.902    -33.5167     -70.7667
# ...                ...              ...         ...         ...          ...
# 7768          147041.0           9802.7       0.735    -33.4589     -70.6989
# 7769           98804.0          14114.9       0.657    -33.5219     -70.6869
# 7772          301313.0           1943.9       0.712    -33.5819     -70.6869
# 7775          241599.0           4474.1       0.743    -33.4861     -70.5333
# 7778           74237.0            589.2       0.749    -33.6669     -70.9308
#
# [4768 rows x 12 columns]

# %%
sns.heatmap(data.corr(), vmin=-1, vmax=1) #Veamos la correlación de todas las features
#Fíjense en la correlación negativa superficie_comuna con densidad_comuna. Tiene bastante sentido, a mayor superficie (denominador), menor es su densidad poblacional
#El area total y el area construida tienen una correlación positiva. Así como el area construida y los baños y dormitorios.
# Out:
# <Axes: >

# %%
plt.bar(height = data.corr()["price"], x = data.corr()["price"].index)
plt.title("Correlación respecto al precio")
plt.xticks(rotation=90)
plt.show()
#Podemos decir que la densidad comunal es agnóstica al precio de la vivienda.
#Las únicas features con una correlación negativa son la superficie de la comuna y su población.
#Respecto al resto de features, mientras mas tenga, mas caro.

# %%
sns.jointplot(data, x = "total_area", y = "price", kind="hex") #Por ejemplo, correlación entre el area total y el precio

# %%
sns.jointplot(data, x = "idh_comuna", y = "price", kind="hex") #Por ejemplo, correlación entre el IDH y el precio

# %%
## Con eso terminamos la etapa de feature engineering y EDA, vamos a hacer ML ahora :D

# %% [markdown]
# ## Training model

# %%
y = data.price #Dejemos en la variable X las features
X = data.drop(columns="price") #Y en y a la respuesta (price)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42) #Separemos los datos en conjuntos de training y testing

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train) #Primero, estandaricemos los datos (Siempre es una buena idea)
X_test = ss.transform(X_test) #Recuerden que se debe tomar como referencia al conjunto de training y luego aplicar al testing
#Nunca estandarizar todo junto!!

# %%
#Entrenemos sin cross validation primero
for lr in LinearRegression(), Ridge(), Lasso(): #Probemos los 3 modelos que vimos en clases
    lr.fit(X_train, y_train) #Entrenamos
    y_pred = lr.predict(X_train) #Predecimos
    sns.scatterplot(x = y_train, y = y_pred, alpha=0.5, s=5) #Este es el comportamiento del modelo lineal
    plt.plot([0,30000], [0,30000], c = "red", linestyle="--") #Hacemos una linea diagonal para representar un modelo "perfecto"
    plt.title(f"{lr.__str__()}, R2: { round(lr.score(X_train, y_train), 5)}") #Imprimimos el nombre del modelo y su R2
    plt.xlabel("y_true")
    plt.ylabel("y_pred")
    plt.show()
    #Las 3 se ven mas o menos igual

# %%
lr = LinearRegression() #Entrenemos un modelo lineal simple
lr.fit(X_train, y_train)
coefs = pd.DataFrame(lr.coef_, columns=["coef"]) #Obtengamos los coeficientes / pesos / w.
coefs["feature"] = X.columns #Agreguemos el nombre de la columna asociado a ese coeficiente.
sns.barplot(coefs, y="coef", x="feature")
plt.xticks(rotation=90)
plt.title("Coeficients W")
plt.show() #Podemos interpretar la "importancia" de las features al momento de predecir respecto al precio.
#Fíjense que una comuna con mayor población impacta negatívamente en el precio de las casas.
#El IDH de la comuna parece ser el factor mas importante al momento de encarecer una propiedad.
#Podemos dar una interpretación a la posición tambien. Comunas que quedan mas hacia el oeste parecen tener un factor positivo al momento de valorar la casa. 
#Lógicamente, el área total de la propiedad encarece la casa

# %%
#El intercept o bias corresponde al valor que tendría una casa si todas sus features fueran equivalentes a 0.
float(lr.intercept_)
# Out:
# 5961.226510067117

# %%
#Evaluemos la generalización del modelo usando cross validation. 
lr = LinearRegression()
cv_score = cross_validate(lr, X_train, y_train)["test_score"]
print("Mean cv:", float(cv_score.mean().round(3)), "Std cv:", float(cv_score.std().round(3)))
#La desviación estandar es muy pequeña (2er decimal) y si bien el R2 disminuye un poco, no es tan significativo.
# Out:
# Mean cv: 0.812 Std cv: 0.014

# %%
def train_poly(X_train, y_train, degree): #Hagamos esta función para entrenar un pipeline incorporando un termino polinomial y una regresion l2
    #Finalmente, agreguemos un término polinomial a la regresión. 
    pf = PolynomialFeatures(degree = degree) #Transforma la matriz agregando terminos polinomiales
    lr = Ridge() #Apply linear regr + L2 norm
    pipe = Pipeline( #Concatenar procesos
        [
            ("polynomial", pf),
            ("linear regression", lr)
        ]
    )
    cv_score = cross_validate(pipe, X_train, y_train)["test_score"] #Entrenemos usando cross validation
    print("Mean cv:", float(cv_score.mean().round(3)), "Std cv:", float(cv_score.std().round(3)), end="\n")

# %%
for degree in range(1, 6):
    print("Degree:", degree)
    train_poly(X_train, y_train, degree)
#Nuestro máximo desempeño lo logramos con una función de grado 2. Con este grado la desviación estandar sigue siendo pequeña (~1.5%)
#A mayor grado aumenta la dispersión. Recuerden Bias - Variance decomposition.
# Out:
# Degree: 1
# Mean cv: 0.812 Std cv: 0.014
# Degree: 2
# Mean cv: 0.875 Std cv: 0.013
# Degree: 3
# Mean cv: 0.872 Std cv: 0.014
# Degree: 4
# Mean cv: 0.657 Std cv: 0.083
# Degree: 5
# Mean cv: -4.239 Std cv: 3.784

# %%
#Verifiquemos el desepeño en nuevos datos (X_test)
degree = 2 #Usemos el grado 2
pf = PolynomialFeatures(degree = degree) #Transforma la matriz agregando terminos polinomiales
lr = Ridge() #Apply linear regr + L2 norm
pipe = Pipeline( #Concatenar procesos
    [
        ("polynomial", pf),
        ("linear_regression", lr)
    ]
)
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

# %%
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred))) #Nuestro error promedio en la misma unidad de la respuesta (UF)
print("MAE", mean_absolute_error(y_test, y_pred)) #El error absoluto, si no nos interesan tanto los outliers.
print("R2", r2_score(y_test, y_pred)) #Nuestra varianza explicada ~0.9
print("r", np.sqrt(r2_score(y_test, y_pred))) #El coeficiente de correlación r es la raiz del r^2
# Out:
# RMSE 1673.823198159617
# MAE 1112.6131005686684
# R2 0.8684236772164673
# r 0.9318925244986501

# %%
sns.scatterplot(x = y_test, y = y_pred, alpha=0.5, s=5) #Este es el comportamiento del modelo lineal
plt.plot([0,30000], [0,30000], c = "red", linestyle="--") #Hacemos una linea diagonal
plt.title(f"Ridge model, degree: 2, R2: { round(pipe.score(X_test, y_test), 5)}")
plt.xlabel("y_true")
plt.ylabel("y_pred")
plt.show()
