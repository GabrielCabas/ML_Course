# %% [markdown]
# ## Star classification

# %% [markdown]
# https://www.kaggle.com/datasets/fedesoriano/stellar-classification-dataset-sdss17

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split #Importar train_test_split and cross validate
from sklearn.linear_model import LogisticRegression #Importar LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix #Importar classification_report y confusion_matrix
from sklearn.pipeline import Pipeline #Importar Pipeline
from sklearn.preprocessing import StandardScaler #Importar StandardScaler
from sklearn.model_selection import GridSearchCV #Importar GridSearchCV

# %%
data = pd.read_csv("../datasets\star_classification.csv")

# %% [markdown]
# ## EDA

# %%
data.describe()
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# 25%        18.965230      18.135828      17.732285      17.460677
# 50%        21.099835      20.125290      19.405145      19.004595
# 75%        22.123767      21.044785      20.396495      19.921120
# max        31.602240      29.571860      32.141470      29.383740
#
#               run_ID  rerun_ID        cam_col       field_ID   spec_obj_ID  \
# count  100000.000000  100000.0  100000.000000  100000.000000  1.000000e+05
# mean     4481.366060     301.0       3.511610     186.130520  5.783882e+18
# std      1964.764593       0.0       1.586912     149.011073  3.324016e+18
# min       109.000000     301.0       1.000000      11.000000  2.995191e+17
# 25%      3187.000000     301.0       2.000000      82.000000  2.844138e+18
# 50%      4188.000000     301.0       4.000000     146.000000  5.614883e+18
# 75%      5326.000000     301.0       5.000000     241.000000  8.332144e+18
# max      8162.000000     301.0       6.000000     989.000000  1.412694e+19
#
#             redshift          plate            MJD       fiber_ID
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.576661    5137.009660   55588.647500     449.312740
# std         0.730707    2952.303351    1808.484233     272.498404
# min        -0.009971     266.000000   51608.000000       1.000000
# 25%         0.054517    2526.000000   54234.000000     221.000000
# 50%         0.424173    4987.000000   55868.500000     433.000000
# 75%         0.704154    7400.250000   56777.000000     645.000000
# max         7.011245   12547.000000   58932.000000    1000.000000

# %%
data = data.drop(columns=["obj_ID", "run_ID", "rerun_ID", "cam_col", "field_ID", "spec_obj_ID", "fiber_ID"])

# %%
data
# Out:
#             alpha      delta         u         g         r         i  \
# 0      135.689107  32.494632  23.87882  22.27530  20.39501  19.16573
# 1      144.826101  31.274185  24.77759  22.83188  22.58444  21.16812
# 2      142.188790  35.582444  25.26307  22.66389  20.60976  19.34857
# 3      338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454
# 4      345.282593  21.183866  19.43718  17.58028  16.49747  15.97711
# ...           ...        ...       ...       ...       ...       ...
# 99995   39.620709  -2.594074  22.16759  22.97586  21.90404  21.30548
# 99996   29.493819  19.798874  22.69118  22.38628  20.45003  19.75759
# 99997  224.587407  15.700707  21.16916  19.26997  18.20428  17.69034
# 99998  212.268621  46.660365  25.35039  21.63757  19.91386  19.07254
# 99999  196.896053  49.464643  22.62171  21.79745  20.60115  20.00959
#
#               z   class  redshift  plate    MJD
# 0      18.79371  GALAXY  0.634794   5812  56354
# 1      21.61427  GALAXY  0.779136  10445  58158
# 2      18.94827  GALAXY  0.644195   4576  55592
# 3      19.25010  GALAXY  0.932346   9149  58039
# 4      15.54461  GALAXY  0.116123   6121  56187
# ...         ...     ...       ...    ...    ...
# 99995  20.73569  GALAXY  0.000000   9374  57749
# 99996  19.41526  GALAXY  0.404895   7626  56934
# 99997  17.35221  GALAXY  0.143366   2764  54535
# 99998  18.62482  GALAXY  0.455040   6751  56368
# 99999  19.28075  GALAXY  0.542944   7410  57104
#
# [100000 rows x 11 columns]

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 10), constrained_layout=True)
for index, column in enumerate(data.drop(columns=["class"]).columns):
    sns.boxplot(data, x = column, ax=axes[index//5, index%5])
    axes[index//5, index%5].set_title(column)
plt.show()

# %%
data = data[(data["u"] != -9999) | (data["g"] != -9999) | (data["z"] != -9999)]
data
# Out:
#             alpha      delta         u         g         r         i  \
# 0      135.689107  32.494632  23.87882  22.27530  20.39501  19.16573
# 1      144.826101  31.274185  24.77759  22.83188  22.58444  21.16812
# 2      142.188790  35.582444  25.26307  22.66389  20.60976  19.34857
# 3      338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454
# 4      345.282593  21.183866  19.43718  17.58028  16.49747  15.97711
# ...           ...        ...       ...       ...       ...       ...
# 99995   39.620709  -2.594074  22.16759  22.97586  21.90404  21.30548
# 99996   29.493819  19.798874  22.69118  22.38628  20.45003  19.75759
# 99997  224.587407  15.700707  21.16916  19.26997  18.20428  17.69034
# 99998  212.268621  46.660365  25.35039  21.63757  19.91386  19.07254
# 99999  196.896053  49.464643  22.62171  21.79745  20.60115  20.00959
#
#               z   class  redshift  plate    MJD
# 0      18.79371  GALAXY  0.634794   5812  56354
# 1      21.61427  GALAXY  0.779136  10445  58158
# 2      18.94827  GALAXY  0.644195   4576  55592
# 3      19.25010  GALAXY  0.932346   9149  58039
# 4      15.54461  GALAXY  0.116123   6121  56187
# ...         ...     ...       ...    ...    ...
# 99995  20.73569  GALAXY  0.000000   9374  57749
# 99996  19.41526  GALAXY  0.404895   7626  56934
# 99997  17.35221  GALAXY  0.143366   2764  54535
# 99998  18.62482  GALAXY  0.455040   6751  56368
# 99999  19.28075  GALAXY  0.542944   7410  57104
#
# [99999 rows x 11 columns]

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 10), constrained_layout=True)
for index, column in enumerate(data.drop(columns=["class"]).columns):
    sns.histplot(data, x = column, ax=axes[index//5, index%5], bins=100)
    axes[index//5, index%5].set_title(column)
plt.show()

# %%
data = data[["u","g","r","i","z", "class", "redshift"]]
#Selecciono columnas importantes
#data #Display

# %%
X = data.drop(columns=["class"]) #X es el conjunto de datos sin la clase
y = data["class"] #y es la clase

# %%
correlation_matrix = X.corr() #Calcula la matriz de correlacion
sns.heatmap(correlation_matrix, annot=True) #Plots heatmap
#Redundancia en las features
# Out:
# <Axes: >

# %% [markdown]
# ## Train model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #Dividir los datos en train y test

# %%
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression())
]
)

params = {
        "model__solver": ["saga"],
        "model__l1_ratio": [0, 0.3, 0.5, 0.7, 1],
        "model__max_iter": [100],
        "model__C": [1, 5, 10, 50]
    }

grid_search = GridSearchCV(pipeline, params, cv=5, scoring="roc_auc_ovr", n_jobs=12, verbose = 1)
grid_search.fit(X_train, y_train)
display(grid_search.best_params_)
display(grid_search.best_score_)
pipeline = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\Gabriel\anaconda3\envs\ml_course\lib\site-packages\sklearn\linear_model\_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# c:\Users\Gabriel\anaconda3\envs\ml_course\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# {'model__C': 50,
#  'model__l1_ratio': 0,
#  'model__max_iter': 200,
#  'model__solver': 'saga'}
# np.float64(0.988070039408153)

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        6.235651      0.099863         0.040349        0.004136
# 1        6.224082      0.063624         0.043984        0.001839
# 2        5.819238      0.360525         0.040848        0.003733
# 3        5.607382      0.093983         0.043727        0.003373
# 4        5.674775      0.209927         0.046464        0.003293
# 5        7.880067      0.030950         0.044288        0.002122
# 6        7.991751      0.036182         0.042033        0.004168
# 7        8.035600      0.104288         0.042476        0.002818
# 8        8.029101      0.067665         0.042390        0.003419
# 9        7.856492      0.310431         0.040861        0.003007
# 10       7.591101      0.072602         0.039815        0.002168
# 11       7.580122      0.027306         0.041186        0.002579
# 12       7.739999      0.130736         0.043204        0.001673
# 13       7.849587      0.021576         0.041514        0.002588
# 14       8.022005      0.155279         0.042858        0.002809
# 15       8.241114      0.076437         0.046364        0.003104
# 16       8.406860      0.149504         0.051202        0.007856
# 17       9.038425      0.032633         0.040859        0.003522
# 18       8.984668      0.043615         0.037462        0.001943
# 19       6.488534      1.333630         0.028784        0.002019
#
#     param_model__C  param_model__l1_ratio  param_model__max_iter  \
# 0                1                    0.0                    200
# 1                1                    0.3                    200
# 2                1                    0.5                    200
# 3                1                    0.7                    200
# 4                1                    1.0                    200
# 5                5                    0.0                    200
# 6                5                    0.3                    200
# 7                5                    0.5                    200
# 8                5                    0.7                    200
# 9                5                    1.0                    200
# 10              10                    0.0                    200
# 11              10                    0.3                    200
# 12              10                    0.5                    200
# 13              10                    0.7                    200
# 14              10                    1.0                    200
# 15              50                    0.0                    200
# 16              50                    0.3                    200
# 17              50                    0.5                    200
# 18              50                    0.7                    200
# 19              50                    1.0                    200
#
#    param_model__solver                                             params  \
# 0                 saga  {'model__C': 1, 'model__l1_ratio': 0, 'model__...
# 1                 saga  {'model__C': 1, 'model__l1_ratio': 0.3, 'model...
# 2                 saga  {'model__C': 1, 'model__l1_ratio': 0.5, 'model...
# 3                 saga  {'model__C': 1, 'model__l1_ratio': 0.7, 'model...
# 4                 saga  {'model__C': 1, 'model__l1_ratio': 1, 'model__...
# 5                 saga  {'model__C': 5, 'model__l1_ratio': 0, 'model__...
# 6                 saga  {'model__C': 5, 'model__l1_ratio': 0.3, 'model...
# 7                 saga  {'model__C': 5, 'model__l1_ratio': 0.5, 'model...
# 8                 saga  {'model__C': 5, 'model__l1_ratio': 0.7, 'model...
# 9                 saga  {'model__C': 5, 'model__l1_ratio': 1, 'model__...
# 10                saga  {'model__C': 10, 'model__l1_ratio': 0, 'model_...
# 11                saga  {'model__C': 10, 'model__l1_ratio': 0.3, 'mode...
# 12                saga  {'model__C': 10, 'model__l1_ratio': 0.5, 'mode...
# 13                saga  {'model__C': 10, 'model__l1_ratio': 0.7, 'mode...
# 14                saga  {'model__C': 10, 'model__l1_ratio': 1, 'model_...
# 15                saga  {'model__C': 50, 'model__l1_ratio': 0, 'model_...
# 16                saga  {'model__C': 50, 'model__l1_ratio': 0.3, 'mode...
# 17                saga  {'model__C': 50, 'model__l1_ratio': 0.5, 'mode...
# 18                saga  {'model__C': 50, 'model__l1_ratio': 0.7, 'mode...
# 19                saga  {'model__C': 50, 'model__l1_ratio': 1, 'model_...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.987544           0.988041           0.986587
# 1            0.987544           0.988041           0.986587
# 2            0.987544           0.988041           0.986587
# 3            0.987544           0.988041           0.986587
# 4            0.987544           0.988041           0.986587
# 5            0.988223           0.988773           0.987228
# 6            0.988223           0.988772           0.987229
# 7            0.988223           0.988773           0.987228
# 8            0.988223           0.988773           0.987228
# 9            0.988223           0.988773           0.987228
# 10           0.988353           0.988913           0.987349
# 11           0.988353           0.988913           0.987349
# 12           0.988353           0.988914           0.987349
# 13           0.988353           0.988913           0.987348
# 14           0.988353           0.988913           0.987349
# 15           0.988473           0.989039           0.987460
# 16           0.988473           0.989039           0.987459
# 17           0.988474           0.989040           0.987458
# 18           0.988473           0.989039           0.987459
# 19           0.988473           0.989039           0.987459
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.986086           0.987197         0.987091        0.000690
# 1            0.986086           0.987197         0.987091        0.000690
# 2            0.986086           0.987197         0.987091        0.000690
# 3            0.986086           0.987197         0.987091        0.000690
# 4            0.986086           0.987197         0.987091        0.000690
# 5            0.986848           0.987969         0.987808        0.000691
# 6            0.986848           0.987969         0.987808        0.000691
# 7            0.986848           0.987969         0.987808        0.000691
# 8            0.986848           0.987969         0.987808        0.000691
# 9            0.986848           0.987969         0.987808        0.000691
# 10           0.986994           0.988117         0.987945        0.000692
# 11           0.986994           0.988116         0.987945        0.000692
# 12           0.986994           0.988115         0.987945        0.000692
# 13           0.986994           0.988116         0.987945        0.000692
# 14           0.986994           0.988116         0.987945        0.000692
# 15           0.987130           0.988248         0.988070        0.000691
# 16           0.987130           0.988247         0.988069        0.000691
# 17           0.987128           0.988245         0.988069        0.000692
# 18           0.987128           0.988246         0.988069        0.000692
# 19           0.987129           0.988246         0.988069        0.000692
#
#     rank_test_score
# 0                20
# 1                17
# 2                19
# 3                16
# 4                18
# 5                12
# 6                13
# 7                11
# 8                15
# 9                14
# 10                7
# 11                6
# 12                9
# 13               10
# 14                8
# 15                1
# 16                2
# 17                4
# 18                5
# 19                3

# %%
y_pred = pipeline.predict(X_train) #Predecir los datos de test
print(classification_report(y_train, y_pred)) #Mostrar el reporte de clasificacion
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.97      0.97     47567
#          QSO       0.94      0.88      0.91     15194
#         STAR       0.96      1.00      0.98     17238
#
#     accuracy                           0.96     79999
#    macro avg       0.96      0.95      0.95     79999
# weighted avg       0.96      0.96      0.96     79999

# %%
y_pred = pipeline.predict(X_test) #Valores totalmente nuevos
y_prob = pipeline.predict_proba(X_test) #Predict probability
print(classification_report(y_test, y_pred)) #Report
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.97      0.97     11878
#          QSO       0.95      0.89      0.92      3767
#         STAR       0.96      1.00      0.98      4355
#
#     accuracy                           0.96     20000
#    macro avg       0.96      0.95      0.95     20000
# weighted avg       0.96      0.96      0.96     20000

# %%
pipeline.named_steps["model"].classes_.tolist()
# Out:
# ['GALAXY', 'QSO', 'STAR']

# %%
labels = pipeline.named_steps["model"].classes_
cm = confusion_matrix(y_test, y_pred, labels=labels)
ax = sns.heatmap(cm, annot=True, fmt="", xticklabels=labels, yticklabels=labels)
ax.set_xlabel("Pred")
ax.set_ylabel("True")
ax.set_title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test == "GALAXY", y_prob[:,0]) #Selecciono las galaxias y la primera columna
plt.plot(fpr, tpr, label ="GALAXY")

fpr, tpr, thresholds = roc_curve(y_test == "STAR", y_prob[:,2]) #Selcciono las estrellas y la 3ra columna
plt.plot(fpr, tpr, label ="STAR")

fpr, tpr, thresholds = roc_curve(y_test == "QSO", y_prob[:,1]) #Selecciono qso y la 2da columna
plt.plot(fpr, tpr, label ="QSO")
plt.legend()
plt.xlabel("False positive Rate")
plt.ylabel("True positive Rate")
plt.show()
